# %% [markdown]
# The following is a visualization of total expenditure on health made per capita in 260 countries in a span of 15 years starting from 1995. This dataset was downloaded from gapminder.org.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.plotting import figure, output_file, show
import pandas as pd
from bokeh.models import ColumnDataSource

output_notebook()

health_exp = pd.read_csv("Health Expenditure.csv", encoding = "ISO-8859-1")
health_exp = health_exp.fillna(0)
health_exp.head(10)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="86d25f59-a2a7-4add-8942-fca116a29a60">Loading BokehJS ...</span>
#     </div>
#   Per capita total expenditure on health         1995         1996  \
# 0                               Abkhazia     0.000000     0.000000
# 1                            Afghanistan     0.000000     0.000000
# 2                  Akrotiri and Dhekelia     0.000000     0.000000
# 3                                Albania   105.870766   145.874213
# 4                                Algeria   192.243807   180.373326
# 5                         American Samoa     0.000000     0.000000
# 6                                Andorra  1468.685064  1596.140032
# 7                                 Angola    68.573562    43.045968
# 8                               Anguilla     0.000000     0.000000
# 9                    Antigua and Barbuda   501.813555   502.271727
#
#           1997         1998         1999         2000         2001  \
# 0     0.000000     0.000000     0.000000     0.000000     0.000000
# 1     0.000000     0.000000     0.000000     0.000000     0.000000
# 2     0.000000     0.000000     0.000000     0.000000     0.000000
# 3   156.120295   183.802111   225.253214   266.395628   279.082481
# 4   196.124726   206.136790   202.622356   188.073681   212.235307
# 5     0.000000     0.000000     0.000000     0.000000     0.000000
# 6  1785.686282  2319.864615  1825.072993  1966.806392  1954.305347
# 7    48.128401    41.652303    44.315755    56.246126    82.236390
# 8     0.000000     0.000000     0.000000     0.000000     0.000000
# 9   527.249278   543.902633   565.256756   584.670400   579.822814
#
#           2002         2003         2004         2005         2006  \
# 0     0.000000     0.000000     0.000000     0.000000     0.000000
# 1    22.114557    29.684998    32.124328    35.577605    36.167636
# 2     0.000000     0.000000     0.000000     0.000000     0.000000
# 3   303.114667   326.034134   379.826416   406.901526   450.944023
# 4   225.208426   234.901186   227.205538   221.502879   232.780189
# 5     0.000000     0.000000     0.000000     0.000000     0.000000
# 6  2152.617156  2225.100628  2327.568749  2476.411767  2850.048649
# 7    63.357726    72.091317    62.970625    71.333321   104.313599
# 8     0.000000     0.000000     0.000000     0.000000     0.000000
# 9   595.292678   641.462200   689.306380   734.333300   815.175285
#
#           2007         2008         2009         2010
# 0     0.000000     0.000000     0.000000     0.000000
# 1    40.358763    38.255108    45.565772    44.465952
# 2     0.000000     0.000000     0.000000     0.000000
# 3   493.882557   557.387321   591.483421   577.275816
# 4   273.055581   299.398716   364.543940   330.006155
# 5     0.000000     0.000000     0.000000     0.000000
# 6  3022.875316  3218.212284  3403.376051  3254.524918
# 7   130.931971   190.840727   297.288639   168.130557
# 8     0.000000     0.000000     0.000000     0.000000
# 9   895.974838   886.946267   872.534416   990.552253

# %% [markdown]
# The dataset has been imported into the pandas dataframe health_exp, and all NaN values have been replaced with zeroes.

# %%
countries = health_exp['Per capita total expenditure on health'].tolist()

years = health_exp.columns.values.tolist()[1:]

data = {}
data['countries'] = countries
for year in years:
    data[year] = health_exp[year].tolist()


p = figure(y_range=countries, plot_height=1000, plot_width = 900, x_range=(0,10000), title="Per capita total expenditure on health")

p.hbar_stack(years, y='countries', height=0.9, color = ['red','blue','green','yellow','black','brown','olive','beige','orange','pink','khaki','grey','navy','teal','magenta','turquoise'], source=ColumnDataSource(data), legend=["%s " % x for x in years])

p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.xaxis.axis_label = 'Per capita total expenditure on health'
p.yaxis.axis_label = 'Countries'
p.legend.location = "center_left"
p.legend.click_policy="hide"


show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6f964fea-a41a-43a7-81b3-83e329a65ed0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6f964fea-a41a-43a7-81b3-83e329a65ed0");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f964fea-a41a-43a7-81b3-83e329a65ed0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f964fea-a41a-43a7-81b3-83e329a65ed0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"986bb51a-7927-43b6-a8cf-794b6bf8eada":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"f428a269-6d66-4f32-84be-f8ea92e54eec","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":"f8a99c5e-7d42-44b0-9d93-5615e9959698","type":"Stack"}},"y":{"field":"countries"}},"id":"e234f065-0d76-47a4-8cec-da2d511f27c8","type":"HBar"},{"attributes":{"fill_color":{"value":"teal"},"height":{"value":0.9},"left":{"expr":{"id":"f428a269-6d66-4f32-84be-f8ea92e54eec","type":"Stack"}},"line_color":{"value":"teal"},"right":{"expr":{"id":"f8a99c5e-7d42-44b0-9d93-5615e9959698","type":"Stack"}},"y":{"field":"countries"}},"id":"e5513141-e45c-425d-88df-d5f481a0efae","type":"HBar"},{"attributes":{"label":{"value":"2008 "},"renderers":[{"id":"6b354a36-b89d-4f1c-b2a5-c045bf9d3b8c","type":"GlyphRenderer"}]},"id":"a7985836-5f10-4e10-814f-5eafc27bbc4e","type":"LegendItem"},{"attributes":{"fill_color":{"value":"magenta"},"height":{"value":0.9},"left":{"expr":{"id":"90906b63-a24d-4188-87c2-deee80ae912d","type":"Stack"}},"line_color":{"value":"magenta"},"right":{"expr":{"id":"7b984f8d-3df1-45b7-ba1e-80e3bc28f68b","type":"Stack"}},"y":{"field":"countries"}},"id":"6d071a10-a4dc-4df9-a14a-d839aa851730","type":"HBar"},{"attributes":{"data_source":{"id":"b8cd431d-fad7-42cb-8c42-8ff2508d6df9","type":"ColumnDataSource"},"glyph":{"id":"e5513141-e45c-425d-88df-d5f481a0efae","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e234f065-0d76-47a4-8cec-da2d511f27c8","type":"HBar"},"selection_glyph":null,"view":{"id":"f8067853-5a94-4ef6-9e4f-f4cc79299fda","type":"CDSView"}},"id":"6b354a36-b89d-4f1c-b2a5-c045bf9d3b8c","type":"GlyphRenderer"},{"attributes":{"source":{"id":"b8cd431d-fad7-42cb-8c42-8ff2508d6df9","type":"ColumnDataSource"}},"id":"f8067853-5a94-4ef6-9e4f-f4cc79299fda","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"90906b63-a24d-4188-87c2-deee80ae912d","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":"7b984f8d-3df1-45b7-ba1e-80e3bc28f68b","type":"Stack"}},"y":{"field":"countries"}},"id":"82e95c85-7d32-4332-97c4-9e10fcd140d7","type":"HBar"},{"attributes":{"label":{"value":"2009 "},"renderers":[{"id":"d331d354-9054-4645-b1bc-863eb7baf18d","type":"GlyphRenderer"}]},"id":"c1705136-e82c-4541-a677-4ae7d8e457f4","type":"LegendItem"},{"attributes":{"fill_color":{"value":"turquoise"},"height":{"value":0.9},"left":{"expr":{"id":"8d979cd6-0eac-44f0-9320-9ab9544a196e","type":"Stack"}},"line_color":{"value":"turquoise"},"right":{"expr":{"id":"e4c5cd2a-1908-47aa-8ad9-d2cba501ba15","type":"Stack"}},"y":{"field":"countries"}},"id":"4fc38bec-0fbb-41cd-8a9b-be1cfd5f0797","type":"HBar"},{"attributes":{"data_source":{"id":"b8cd431d-fad7-42cb-8c42-8ff2508d6df9","type":"ColumnDataSource"},"glyph":{"id":"6d071a10-a4dc-4df9-a14a-d839aa851730","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"82e95c85-7d32-4332-97c4-9e10fcd140d7","type":"HBar"},"selection_glyph":null,"view":{"id":"14ed169b-6812-4b67-b0ab-73f35ba31d80","type":"CDSView"}},"id":"d331d354-9054-4645-b1bc-863eb7baf18d","type":"GlyphRenderer"},{"attributes":{"source":{"id":"b8cd431d-fad7-42cb-8c42-8ff2508d6df9","type":"ColumnDataSource"}},"id":"14ed169b-6812-4b67-b0ab-73f35ba31d80","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"8d979cd6-0eac-44f0-9320-9ab9544a196e","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":"e4c5cd2a-1908-47aa-8ad9-d2cba501ba15","type":"Stack"}},"y":{"field":"countries"}},"id":"81518ca9-24f7-43a9-b5b0-95891b75fd6b","type":"HBar"},{"attributes":{"label":{"value":"2010 "},"renderers":[{"id":"6a253f81-53fc-4ad6- ...

# %% [markdown]
# The visualization above is a cluster of stacked horizontal bar glyphs and as an interactive feature, glyphs for individual years can be hidden or be made to appear at the click of button by interaction with the elements in the legend.

# %% [markdown]
# From this visualization, it's very intuitive to infer cumulative expenditure on health per capita starting in 1995, of a country.
# For example, Denmark's cumulative expenditure per capita in the year 2001 is a little over 15500.
#
# In a similar fashion, to infer a specific year's datum associated with a country, just gauge the length of the appropriate colored horizontal bar.
# For example, Canada's expenditure on health per capita in 2001 is approximately 2700.
#
# To drill down on a specific year or to hide a certain year's data, please hide/unhide them by interacting with the legend.
# Please remember to zoom in using the 'wheel zoom' tool on the right of the plot for convenience.
