# %% [markdown]
# The following is a visualization of total expenditure on health made per capita in 260 countries in a span of 15 years starting from 1995. This dataset was downloaded from gapminder.org.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.plotting import figure, output_file, show
import pandas as pd
from bokeh.models import ColumnDataSource

output_notebook()

health_exp = pd.read_csv("Health Expenditure.csv", encoding = "ISO-8859-1")
health_exp = health_exp.fillna(0)
health_exp.head(10)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ee460ed2-575b-4c22-a119-2454e0389ecb">Loading BokehJS ...</span>
#     </div>
#   Per capita total expenditure on health         1995         1996  \
# 0                               Abkhazia     0.000000     0.000000
# 1                            Afghanistan     0.000000     0.000000
# 2                  Akrotiri and Dhekelia     0.000000     0.000000
# 3                                Albania   105.870766   145.874213
# 4                                Algeria   192.243807   180.373326
# 5                         American Samoa     0.000000     0.000000
# 6                                Andorra  1468.685064  1596.140032
# 7                                 Angola    68.573562    43.045968
# 8                               Anguilla     0.000000     0.000000
# 9                    Antigua and Barbuda   501.813555   502.271727
#
#           1997         1998         1999         2000         2001  \
# 0     0.000000     0.000000     0.000000     0.000000     0.000000
# 1     0.000000     0.000000     0.000000     0.000000     0.000000
# 2     0.000000     0.000000     0.000000     0.000000     0.000000
# 3   156.120295   183.802111   225.253214   266.395628   279.082481
# 4   196.124726   206.136790   202.622356   188.073681   212.235307
# 5     0.000000     0.000000     0.000000     0.000000     0.000000
# 6  1785.686282  2319.864615  1825.072993  1966.806392  1954.305347
# 7    48.128401    41.652303    44.315755    56.246126    82.236390
# 8     0.000000     0.000000     0.000000     0.000000     0.000000
# 9   527.249278   543.902633   565.256756   584.670400   579.822814
#
#           2002         2003         2004         2005         2006  \
# 0     0.000000     0.000000     0.000000     0.000000     0.000000
# 1    22.114557    29.684998    32.124328    35.577605    36.167636
# 2     0.000000     0.000000     0.000000     0.000000     0.000000
# 3   303.114667   326.034134   379.826416   406.901526   450.944023
# 4   225.208426   234.901186   227.205538   221.502879   232.780189
# 5     0.000000     0.000000     0.000000     0.000000     0.000000
# 6  2152.617156  2225.100628  2327.568749  2476.411767  2850.048649
# 7    63.357726    72.091317    62.970625    71.333321   104.313599
# 8     0.000000     0.000000     0.000000     0.000000     0.000000
# 9   595.292678   641.462200   689.306380   734.333300   815.175285
#
#           2007         2008         2009         2010
# 0     0.000000     0.000000     0.000000     0.000000
# 1    40.358763    38.255108    45.565772    44.465952
# 2     0.000000     0.000000     0.000000     0.000000
# 3   493.882557   557.387321   591.483421   577.275816
# 4   273.055581   299.398716   364.543940   330.006155
# 5     0.000000     0.000000     0.000000     0.000000
# 6  3022.875316  3218.212284  3403.376051  3254.524918
# 7   130.931971   190.840727   297.288639   168.130557
# 8     0.000000     0.000000     0.000000     0.000000
# 9   895.974838   886.946267   872.534416   990.552253

# %% [markdown]
# The dataset has been imported into the pandas dataframe health_exp, and all NaN values have been replaced with zeroes.

# %%
countries = health_exp['Per capita total expenditure on health'].tolist()

years = health_exp.columns.values.tolist()[1:]

data = {}
data['countries'] = countries
for year in years:
    data[year] = health_exp[year].tolist()


p = figure(y_range=countries, plot_height=1000, plot_width = 900, x_range=(0,10000), title="Healthcare Expenditure")

p.hbar_stack(years, y='countries', height=0.9, color = ['red','blue','green','yellow','black','brown','olive','beige','orange','pink','khaki','grey','navy','teal','magenta','turquoise'], source=ColumnDataSource(data), legend=["%s " % year for year in years])

p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.xaxis.axis_label = 'Per capita total expenditure on health'
p.yaxis.axis_label = 'Countries'
p.legend.location = "center_left"
p.legend.click_policy="hide"


show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="22287764-8e08-4aa9-add1-d9811e3f15e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("22287764-8e08-4aa9-add1-d9811e3f15e5");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("22287764-8e08-4aa9-add1-d9811e3f15e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '22287764-8e08-4aa9-add1-d9811e3f15e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b1ae0fd6-0393-4e63-807b-d9e49667e1af":{"roots":{"references":[{"attributes":{"source":{"id":"822b7518-a627-4b3c-9c45-00c0b0625cd8","type":"ColumnDataSource"}},"id":"6c7983b1-11e5-4545-96a6-68f3811a4708","type":"CDSView"},{"attributes":{"label":{"value":"1999 "},"renderers":[{"id":"2e433034-1937-41f7-b13b-439b4db22ff1","type":"GlyphRenderer"}]},"id":"28c6ce9d-1f79-4b9b-abf8-0ebbf2e82ea0","type":"LegendItem"},{"attributes":{"fill_color":{"value":"black"},"height":{"value":0.9},"left":{"expr":{"id":"a7a64de4-a892-4f02-96d8-42dc4394a966","type":"Stack"}},"right":{"expr":{"id":"ebe529bc-72e9-4d14-a9f3-f8b7e1365115","type":"Stack"}},"y":{"field":"countries"}},"id":"9b64e136-ffcf-4547-966c-8278dd508bac","type":"HBar"},{"attributes":{"fill_color":{"value":"blue"},"height":{"value":0.9},"left":{"expr":{"id":"7fa26fc5-4660-41bb-bc7f-8255a361c570","type":"Stack"}},"line_color":{"value":"blue"},"right":{"expr":{"id":"54884b93-c56b-4d66-9587-c7978261b278","type":"Stack"}},"y":{"field":"countries"}},"id":"c7f0be38-6c1d-4b7b-9f94-672904abf4ca","type":"HBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"7fa26fc5-4660-41bb-bc7f-8255a361c570","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":"54884b93-c56b-4d66-9587-c7978261b278","type":"Stack"}},"y":{"field":"countries"}},"id":"7e1487a9-081a-4fe7-8f96-bc63b2498e15","type":"HBar"},{"attributes":{"label":{"value":"1996 "},"renderers":[{"id":"e4597a68-c2a8-474d-a013-665955bd9325","type":"GlyphRenderer"}]},"id":"03a05c07-d7b6-46fa-8452-5ba84d946c70","type":"LegendItem"},{"attributes":{"fill_color":{"value":"green"},"height":{"value":0.9},"left":{"expr":{"id":"f86305b6-bcc6-4d42-9585-d74d4d024f93","type":"Stack"}},"line_color":{"value":"green"},"right":{"expr":{"id":"a1cdbb16-c445-408f-b5f7-4c3cc4a09f09","type":"Stack"}},"y":{"field":"countries"}},"id":"d09e1e6c-3a5c-4df3-b767-3d14407ab54c","type":"HBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"f86305b6-bcc6-4d42-9585-d74d4d024f93","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":"a1cdbb16-c445-408f-b5f7-4c3cc4a09f09","type":"Stack"}},"y":{"field":"countries"}},"id":"6bf0be8d-6364-4b4b-8ef6-f44077cc05ae","type":"HBar"},{"attributes":{"label":{"value":"1997 "},"renderers":[{"id":"29a5aea9-892e-4bcf-be85-23a31b0b86c1","type":"GlyphRenderer"}]},"id":"58cf5ae7-f706-42bf-b3e5-7e4cec47471b","type":"LegendItem"},{"attributes":{"source":{"id":"822b7518-a627-4b3c-9c45-00c0b0625cd8","type":"ColumnDataSource"}},"id":"2983c5d3-a6fa-4294-bfee-d593e063c4ad","type":"CDSView"},{"attributes":{"data_source":{"id":"822b7518-a627-4b3c-9c45-00c0b0625cd8","type":"ColumnDataSource"},"glyph":{"id":"c7f0be38-6c1d-4b7b-9f94-672904abf4ca","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7e1487a9-081a-4fe7-8f96-bc63b2498e15","type":"HBar"},"selection_glyph":null,"view":{"id":"4030b240-e7f4-4d86-b39a-0eef978a5cea","type":"CDSView"}},"id":"e4597a68-c2a8-474d-a013-665955bd9325","type":"GlyphRenderer"},{"attributes":{"source":{"id":"822b7518-a627-4b3c-9c45-00c0b0625cd8","type":"ColumnDataSource"}},"id":"4030b240-e7f4-4d86-b39a-0eef978a5cea","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"a7a64de4-a892-4f02-96d8-42dc4394a966","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":"ebe529bc-72e9-4d14-a9f3-f8b7e1365115","type":"Stack"}},"y":{"field":"countries"}},"id":"7f9cef49-f784-4f22-8d74-686db633688a","type":"HBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"966b6c7d-25d9-429f-b680-d109f4fb5858","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value": ...

# %% [markdown]
# The visualization above is a cluster of stacked horizontal bar glyphs and as an interactive feature, glyphs for individual years can be hidden or be made to appear at the click of button by interaction with the elements in the legend.

# %% [markdown]
# From this visualization, it's very intuitive to infer cumulative expenditure on health per capita starting in 1995, of a country.
# For example, Denmark's cumulative expenditure per capita in the year 2001 is a little over 15500.
#
# In a similar fashion, to infer a specific year's datum associated with a country, just gauge the length of the appropriate colored horizontal bar.
# For example, Canada's expenditure on health per capita in 2001 is approximately 2700.
#
# To drill down on a specific year or to hide a certain year's data, please hide/unhide them by interacting with the legend.
# Please remember to zoom in using the 'wheel zoom' tool on the right of the plot for convenience.
