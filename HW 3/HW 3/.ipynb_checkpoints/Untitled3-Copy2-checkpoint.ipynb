# %%
import pandas as pd
import numpy as np
from bokeh.io import output_notebook, show, curdoc, push_notebook
from bokeh.models import ColumnDataSource,HoverTool,ColorBar
from bokeh.plotting import figure, show, output_notebook
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from bokeh.layouts import layout
from bokeh.layouts import row
from ipywidgets import interact

output_notebook()

data = pd.read_csv('Wholesale customers data.csv')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2224621f-9e5d-4f0a-93ff-1297ec1071b5">Loading BokehJS ...</span>
#     </div>

# %%
data = data.drop('Channel',axis=1)
data = data.drop('Region',axis=1)
data.head(10)
# Out:
#    Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669   9656     7561     214              2674        1338
# 1   7057   9810     9568    1762              3293        1776
# 2   6353   8808     7684    2405              3516        7844
# 3  13265   1196     4221    6404               507        1788
# 4  22615   5410     7198    3915              1777        5185
# 5   9413   8259     5126     666              1795        1451
# 6  12126   3199     6975     480              3140         545
# 7   7579   4956     9426    1669              3321        2566
# 8   5963   3648     6192     425              1716         750
# 9   6006  11093    18881    1159              7425        2098

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(data[['Milk','Grocery']])
data['cluster'] = kmeans.labels_

colormap = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'black', 6: 'navy', 7: 'pink'}
colors = [colormap[x] for x in data['cluster']]

p = figure(title = "Wholesale Customers Data", tools="hover,lasso_select,pan,wheel_zoom,box_zoom,reset,save")
p.xaxis.axis_label = 'Milk'
p.yaxis.axis_label = 'Grocery' 

x = data['Milk'].tolist()
y = data['Grocery'].tolist()

r = p.circle(x, y, color=colors, fill_alpha=0.2, size=10)

def update(x,y):
    r.data_source.data['x'] = data[x]
    r.data_source.data['y'] = data[y]
    p.xaxis.axis_label = x
    p.yaxis.axis_label = y
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2f8deaa5-cb26-42e4-93ae-15a635b76fcb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("2f8deaa5-cb26-42e4-93ae-15a635b76fcb");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f8deaa5-cb26-42e4-93ae-15a635b76fcb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f8deaa5-cb26-42e4-93ae-15a635b76fcb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f40f621-3004-4091-9ff0-ec9febcd3fc1":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"66e3e1f6-2667-4e39-9e74-b905556d8668","type":"PolyAnnotation"}},"id":"128b5c3e-2b91-4f7e-9139-bde948562732","type":"LassoSelectTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"e3928e19-dbb9-4afd-840d-24d2916ac880","type":"Circle"},{"attributes":{},"id":"b87023db-3b8c-42ff-8ecd-499c960b0775","type":"SaveTool"},{"attributes":{"overlay":{"id":"45d6d0c4-be5a-451b-884b-b0727ae23af1","type":"BoxAnnotation"}},"id":"1e35a848-4b4f-44bf-a75d-748242884fca","type":"BoxZoomTool"},{"attributes":{},"id":"9b899d14-7a2c-4a81-9fd9-a08ec6016148","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"5593ec10-0d0f-4c1c-ae8d-7efce5a25fd3","type":"LinearAxis"}],"left":[{"id":"ca08d8f3-b051-4b02-b15d-3fc641a0f9e2","type":"LinearAxis"}],"renderers":[{"id":"5593ec10-0d0f-4c1c-ae8d-7efce5a25fd3","type":"LinearAxis"},{"id":"0009cb22-e8f7-471a-a72b-496b94ab8441","type":"Grid"},{"id":"ca08d8f3-b051-4b02-b15d-3fc641a0f9e2","type":"LinearAxis"},{"id":"2bd0349e-2527-4609-8d06-715e9b55fece","type":"Grid"},{"id":"66e3e1f6-2667-4e39-9e74-b905556d8668","type":"PolyAnnotation"},{"id":"45d6d0c4-be5a-451b-884b-b0727ae23af1","type":"BoxAnnotation"},{"id":"06b0fa1d-69a3-442c-b0f6-0f413d9a6ed5","type":"GlyphRenderer"}],"title":{"id":"6b820226-7a31-425a-86c6-4d3a183830e5","type":"Title"},"toolbar":{"id":"0983409a-05a3-4cae-8ca8-f881804aa609","type":"Toolbar"},"x_range":{"id":"3efd01d9-84f1-4e55-8813-955e018e1620","type":"DataRange1d"},"x_scale":{"id":"65e25782-ef0c-41ad-89ab-260998f0bd40","type":"LinearScale"},"y_range":{"id":"69ad8a55-b99e-4aa1-9d4a-e81e1cdf89c2","type":"DataRange1d"},"y_scale":{"id":"c54432d5-cc23-47ad-8304-76feaa92668f","type":"LinearScale"}},"id":"e1a0bc7e-dd20-415f-9616-b0ef8c94e22e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Wholesale Customers Data"},"id":"6b820226-7a31-425a-86c6-4d3a183830e5","type":"Title"},{"attributes":{},"id":"37279994-00fb-431e-9789-a9e7ac6970ef","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"e1a0bc7e-dd20-415f-9616-b0ef8c94e22e","subtype":"Figure","type":"Plot"},"ticker":{"id":"37279994-00fb-431e-9789-a9e7ac6970ef","type":"BasicTicker"}},"id":"2bd0349e-2527-4609-8d06-715e9b55fece","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"66e3e1f6-2667-4e39-9e74-b905556d8668","type":"PolyAnnotation"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"31284ac5-e074-4e73-848f-9f9331ded44b","type":"Circle"},{"attributes":{},"id":"39f814de-9c03-4fd9-a5cb-11a5c096f1fa","type":"BasicTickFormatter"},{"attributes":{},"id":"3722f5c2-7eda-413b-ab96-b9e82d393fbb","type":"ResetTool"},{"attributes":{"callback":null},"id":"8385f329-3df0-4b7e-a689-1b5420a093f0","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["x","y","fill_color","line_color"],"data":{"fill_color":["yellow","yellow","yellow","red","red","red","red","yellow","red","yellow","yellow","red","yellow","yellow","yellow","red","yellow","red","yellow","yellow","red","red","red","blue","yellow","red","red","red","blue","red","yellow","red","red","red","red","yellow","red","yellow","blue","red","red","red","yellow","blue","yellow","blue","blue","green","yellow","blue","red","red","red","yellow","red","red","blue","yellow","red","yellow","red","green","red","yellow","red","blue","red","yellow","red","red","red","yellow","red","yellow","yellow","red","red","blue" ...

# %%
interact(update, x = list(data.columns)[:-1], y = list(data.columns)[:-1])
# Out:
# <function __main__.update>

# %%
kmeans.n_clusters
# Out:
# 4

# %%
r.data_source.data['x']
# Out:
# 0       9656
# 1       9810
# 2       8808
# 3       1196
# 4       5410
# 5       8259
# 6       3199
# 7       4956
# 8       3648
# 9      11093
# 10      5403
# 11      1124
# 12     12319
# 13      6208
# 14      9465
# 15      1114
# 16      8816
# 17      6157
# 18      6327
# 19      2495
# 20      4519
# 21       871
# 22      1917
# 23     36423
# 24      9776
# 25      4230
# 26       961
# 27       803
# 28     20484
# 29      2100
#        ...
# 410     2096
# 411     3289
# 412     3605
# 413     4859
# 414     1990
# 415     6046
# 416    10940
# 417     5499
# 418     8494
# 419     3783
# 420     5266
# 421     4847
# 422     1377
# 423     3686
# 424     2884
# 425     2408
# 426     9347
# 427    16687
# 428     5970
# 429     1750
# 430     4230
# 431     5506
# 432     1162
# 433     3218
# 434     3922
# 435    12051
# 436     1431
# 437    15488
# 438     1981
# 439     1698
# Name: Milk, Length: 440, dtype: int64
