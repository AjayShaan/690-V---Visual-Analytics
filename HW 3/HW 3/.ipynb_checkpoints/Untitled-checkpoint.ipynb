# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource,HoverTool,ColorBar
from bokeh.plotting import figure, show, output_file

output_notebook()

df = pd.read_csv('Wholesale customers data.csv')
df['ID'] = df['Channel'].astype(str) + df['Region'].astype(str)
df = df.drop('Channel',axis=1)
df = df.drop('Region',axis=1)

km = KMeans(n_clusters=6, random_state=1)
store_distances = km.fit_transform(stores.iloc[:, 2:])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="84ab1a5c-b051-4cba-a126-12a36012f925">Loading BokehJS ...</span>
#     </div>

# %%
store_distances
# Out:
# array([[ 50946.43177779,  16185.19667175,   9963.20319619,  11793.73547924,
#          40383.61258908,  70494.70135606],
#        [ 51231.46057085,  12405.2243879 ,   8538.48368102,  16807.902526  ,
#          45885.59606878,  69884.78660825],
#        [ 49676.16003902,  15347.68133577,   9539.61813081,  17796.56077288,
#          46586.23643657,  72048.56440818],
#        ...,
#        [ 54056.64760128,  15272.16145716,  32732.25480166,  31868.1344669 ,
#          48765.43977588,  45987.78574665],
#        [ 53653.29334616,  23220.49789211,   5444.85601443,  12488.60944315,
#          42396.41991164,  79722.96072074],
#        [ 57867.95169368,  22735.86461853,   4923.60964031,  19854.85240527,
#          49987.6215415 ,  81393.97446175]])

# %%
labels = km.labels_
print(pd.crosstab(labels, df["ID"]))
# Out:
# ID     11  12   13  21  22  23
# row_0
# 0       0   1    2   0   0   0
# 1       2   0    3  12  10  47
# 2      37  19  134   5   5  35
# 3      17   8   58   1   3  17
# 4       3   0   14   0   0   2
# 5       0   0    0   0   1   4

# %%
p = figure(title = "Wholesale Customers Data", tools="hover,lasso_select,pan,wheel_zoom,box_zoom,reset,save")

p.asterisk(x=store_distances[:,0], y=store_distances[:,1], size=12)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2a9a8914-6456-4764-89db-c06028fbff4f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("2a9a8914-6456-4764-89db-c06028fbff4f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2a9a8914-6456-4764-89db-c06028fbff4f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2a9a8914-6456-4764-89db-c06028fbff4f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8c28a84d-b7c6-43c7-8d34-575495645a3d":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"63c4fbd1-de12-4b38-834f-8c4f98fb537b","type":"Asterisk"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2c31c852-6060-47c8-8417-43d9e81362c8","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[440]},"y":{"__ndarray__":"...","dtype":"float64","shape":[440]}}},"id":"717ae8cb-ec9a-4c8b-8385-b927e1f9e9f8","type":"ColumnDataSource"},{"attributes":{},"id":"6bfa2eed-3d0d-4e16-b9fe-295e640ed88d","type":"SaveTool"},{"attributes":{"plot":{"id":"e0244222-a1f5-46ed-a9e0-3148bb63fedf","subtype":"Figure","type":"Plot"},"ticker":{"id":"5aa7212d-e4c8-4c9a-9138-4baa576de57d","type":"BasicTicker"}},"id":"dd994c24-49ed-4334-839a-664e1612c8b0","type":"Grid"},{"attributes":{"callback":null},"id":"5a6cf806-5f66-49c4-abc2-1bdc3c34d484","type":"DataRange1d"},{"attributes":{},"id":"898e0f2e-5a85-43db-b1c5-4ad4ded3aeb2","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Wholesale Customers Data"},"id":"68f3ce23-5f42-4140-84d6-111de7e67691","type":"Title"},{"attributes":{"below":[{"id":"ba4d750d-7672-4098-8b6d-5a553239d3bc","type":"LinearAxis"}],"left":[{"id":"eff8d16c-9631-4778-98a7-d75011d4d0c3","type":"LinearAxis"}],"renderers":[{"id":"ba4d750d-7672-4098-8b6d-5a553239d3bc","type":"LinearAxis"},{"id":"dd994c24-49ed-4334-839a-664e1612c8b0","type":"Grid"},{"id":"eff8d16c-9631-4778-98a7-d75011d4d0c3","type":"LinearAxis"},{"id":"f5ec87f3-15cc-4402-9891-196bc0227d65","type":"Grid"},{"id":"a46d96a1-fd40-4909-bbac-29ff69a68fc9","type":"PolyAnnotation"},{"id":"2c31c852-6060-47c8-8417-43d9e81362c8","type":"BoxAnnotation"},{"id":"40fd43ad-283f-4471-a816-1d3281a30a64","type":"GlyphRenderer"}],"title":{"id":"68f3ce23-5f42-4140-84d6-111de7e67691","type":"Title"},"toolbar":{"id":"9e8e6154-d236-493f-92d0-58ac33f3944a","type":"Toolbar"},"x_range":{"id":"5a6cf806-5f66-49c4-abc2-1bdc3c34d484","type":"DataRange1d"},"x_scale":{"id":"17b8a15b-b8fc-4306-b6c0-d87c1f01b74c","type":"LinearScale"},"y_range":{"id":"12bc8371-1975-41a2-885f-dbe68dd2ba0c","type":"DataRange1d"},"y_scale":{"id":"ecec81e0-5f20-496a-bf56-1b81867ab441","type":"LinearScale"}},"id":"e0244222-a1f5-46ed-a9e0-3148bb63fedf","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"1627a62b-9376-4465-bb2e-10c2742a4a37","type":"Asterisk"},{"attributes":{"dimension":1,"plot":{"id":"e0244222-a1f5-46ed-a9e0-3148bb63fedf","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cab8056-92c0-4988-bd62-5021b0b62270","type":"BasicTicker"}},"id":"f5ec87f3-15cc-4402-9891-196bc0227d65","type":"Grid"},{"attributes":{},"id":"4cab8056-92c0-4988-bd62-5021b0b62270","type":"BasicTicker"},{"attributes":{},"id":"ecec81e0-5f20-496a-bf56-1b81867ab441","type":"LinearScale"},{"attributes":{"callback":null},"id":"12bc8371-1975-41a2-885f-dbe68dd2ba0c","type":"DataRange1d"},{"attributes":{},"id":"17b8a15b-b8fc-4306-b6c0-d87c1f01b74c","type":"LinearScale"},{"attributes":{"data_source":{"id":"717ae8cb-ec9a-4c8b-8385-b927e1f9e9f8","type":"ColumnDataSource"},"glyph":{"id":"63c4fbd1-de12-4b38-834f-8c4f98fb537b","type":"Asterisk"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1627a62b-9376-4465-bb2e-10c2742a4a37","type":"Asterisk"},"selection_glyph":null,"view":{"id":"a50a68e9-eb94-4cf4-b6ec-2ec7e12193bd","type":"CDSVi ...
