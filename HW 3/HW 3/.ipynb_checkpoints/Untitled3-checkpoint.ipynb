# %%
import pandas as pd
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource,HoverTool,ColorBar
from bokeh.plotting import figure, show, output_file
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from bokeh.layouts import layout
from bokeh.layouts import row

output_notebook()

data = pd.read_csv('Wholesale customers data.csv')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33a1168e-e63a-433a-aab8-626cae12d131">Loading BokehJS ...</span>
#     </div>

# %%
data = data.drop('Channel',axis=1)
data = data.drop('Region',axis=1)
data.head(10)
# Out:
#    Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669   9656     7561     214              2674        1338
# 1   7057   9810     9568    1762              3293        1776
# 2   6353   8808     7684    2405              3516        7844
# 3  13265   1196     4221    6404               507        1788
# 4  22615   5410     7198    3915              1777        5185
# 5   9413   8259     5126     666              1795        1451
# 6  12126   3199     6975     480              3140         545
# 7   7579   4956     9426    1669              3321        2566
# 8   5963   3648     6192     425              1716         750
# 9   6006  11093    18881    1159              7425        2098

# %%
colormap = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange'}
colors = [colormap[x] for x in data['cluster']]

# %%
def km(no,x,y):
    kmeans = KMeans(n_clusters=no)
    kmeans.fit(data[['Milk','Grocery']])
    data['cluster'] = kmeans.labels_

    p = figure(title = "Wholesale Customers Data", tools="hover,lasso_select,pan,wheel_zoom,box_zoom,reset,save")
    p.xaxis.axis_label = 'Milk'
    p.yaxis.axis_label = 'Grocery'

    p.asterisk(x=data['Milk'], y=data['Grocery'], color=colors, fill_alpha=0.2, size=12)
    show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="930210a3-d9d5-4c97-a031-6b62c659f539"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("930210a3-d9d5-4c97-a031-6b62c659f539");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("930210a3-d9d5-4c97-a031-6b62c659f539");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '930210a3-d9d5-4c97-a031-6b62c659f539' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ea5ef27-4351-404b-833b-73565046f07b":{"roots":{"references":[{"attributes":{},"id":"4af8044c-d1ad-4086-b02c-a4757fc87f5c","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"eb25226e-70ba-48fd-80ce-b1fa6a4532a1","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c9061b0-67c2-4277-a829-3b1f6ae3b6fc","type":"BasicTicker"}},"id":"c1a59c65-5e71-4b49-a967-ab25a78a14bb","type":"Grid"},{"attributes":{},"id":"4c9061b0-67c2-4277-a829-3b1f6ae3b6fc","type":"BasicTicker"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"998b5ad8-b520-4870-9e09-1ff80d62c3fb","type":"BasicTickFormatter"},"plot":{"id":"eb25226e-70ba-48fd-80ce-b1fa6a4532a1","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c9061b0-67c2-4277-a829-3b1f6ae3b6fc","type":"BasicTicker"}},"id":"35e181d9-3db6-4e1e-a2d4-c88924b1b24a","type":"LinearAxis"},{"attributes":{"plot":{"id":"eb25226e-70ba-48fd-80ce-b1fa6a4532a1","subtype":"Figure","type":"Plot"},"ticker":{"id":"3
but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"456a2b9e-72db-4068-a26d-46fec377cff0":{"roots":{"references":[{"attributes":{"children":[{"id":"f74160a3-afdf-4d3e-927e-f73e1c6e5916","type":"Dropdown"}]},"id":"f5a03e3a-c8c5-4cbf-bf1f-31423d54f6bc","type":"WidgetBox"},{"attributes":{"button_type":"warning","callback":null,"icon":null,"label":"Dropdown button","menu":[["Item 1","item_1"],["Item 2","item_2"],null,["Item 3","item_3"]]},"id":"f74160a3-afdf-4d3e-927e-f73e1c6e5916","type":"Dropdown"}],"root_ids":["f5a03e3a-c8c5-4cbf-bf1f-31423d54f6bc"]},"title":"Bokeh Application","version":"0.12.7"}};
#             var render_items = [{"docid":"456a2b9e-72db-4068-a26d-46fec377cff0","elementid":"a63b9678-d517-4f20-add7-d61d3beb6b93","modelid":"f5a03e3a-c8c5-4cbf-bf1f-31423d54f6bc"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((root.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i].call(root, root.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!root._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         root._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("a63b9678-d517-4f20-add7-d61d3beb6b93")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (root._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(window));
# </script>
# W-1004 (BOTH_CHILD_AND_ROOT): Models should not be a document root if they are in a layout box: Figure(id='1962cac8-a7c0-4983-bb15-adc917e1a3bb', ...)
# W-1004 (BOTH_CHILD_AND_ROOT): Models should not be a document root if they are in a layout box: Figure(id='9b01b711-4e25-4c9e-9778-b30583ef6a6b', ...)

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Dropdown
from bokeh.plotting import curdoc

menu = [("Quaterly", "time_windows"), ("Half Yearly", "time_windows"), None, ("Yearly", "time_windows")]
dropdown = Dropdown(label="Time Period", button_type="warning", menu=menu)

def function_to_call(attr, old, new):
    print(dropdown.value)

dropdown.on_change('value', function_to_call)

curdoc().add_root(dropdown)

show(widgetbox(dropdown))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6498b077-e0cf-476b-8984-b5abe5eb6305"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6498b077-e0cf-476b-8984-b5abe5eb6305");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6498b077-e0cf-476b-8984-b5abe5eb6305");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6498b077-e0cf-476b-8984-b5abe5eb6305' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0c9eb6a7-3f29-4c27-89f2-6e0ac40b182f":{"roots":{"references":[{"attributes":{"button_type":"warning","callback":null,"icon":null,"label":"Time Period","menu":[["Quaterly","time_windows"],["Half Yearly","time_windows"],null,["Yearly","time_windows"]]},"id":"60a3f420-8a0d-4484-862d-e417d128f0b8","type":"Dropdown"},{"attributes":{"children":[{"id":"60a3f420-8a0d-4484-862d-e417d128f0b8","type":"Dropdown"}]},"id":"254c2329-89c2-4a47-8673-6456f4d27e1a","type":"WidgetBox"}],"root_ids":["254c2329-89c2-4a47-8673-6456f4d27e1a"]},"title":"Bokeh Application","version":"0.12.7"}};
#             var render_items = [{"docid":"0c9eb6a7-3f29-4c27-89f2-6e0ac40b182f","elementid":"6498b077-e0cf-476b-8984-b5abe5eb6305","modelid":"254c2329-89c2-4a47-8673-6456f4d27e1a"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((root.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i].call(root, root.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!root._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         root._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("6498b077-e0cf-476b-8984-b5abe5eb6305")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (root._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(window));
# </script>
# W-1004 (BOTH_CHILD_AND_ROOT): Models should not be a document root if they are in a layout box: Figure(id='1962cac8-a7c0-4983-bb15-adc917e1a3bb', ...)
# W-1004 (BOTH_CHILD_AND_ROOT): Models should not be a document root if they are in a layout box: Figure(id='9b01b711-4e25-4c9e-9778-b30583ef6a6b', ...)
# W-1004 (BOTH_CHILD_AND_ROOT): Models should not be a document root if they are in a layout box: Dropdown(id='60a3f420-8a0d-4484-862d-e417d128f0b8', ...)
